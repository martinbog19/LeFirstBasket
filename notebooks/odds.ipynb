# %%
import pandas as pd
import json
import requests
import numpy as np
from datetime import datetime, timedelta, timezone
from zoneinfo import ZoneInfo
import pytz
from bs4 import BeautifulSoup
import requests
import os

# %%
import string
from unidecode import unidecode

def normalize_name(x) :

    for suffix in [' Jr.', ' Sr.', ' III', ' II', ' IV', ' Jr', ' Sr'] :
        x = x.replace(suffix, '')
    x = x.translate(str.maketrans('', '', string.punctuation))

    return unidecode(x).lower()

# %%
odds = pd.read_csv('../data/odds_first_basket.csv')[['name']].drop_duplicates()
metadata = pd.read_csv('../data/player_metadata.csv')[['player_id', 'name', 'name_norm']]

# %%
odds['name_norm'] = odds['name'].apply(normalize_name)

# %%
odds.merge(metadata, on = 'name_norm', suffixes = ['_odds', '_md'], how = 'left').tail(50)
# Out:
#                name_odds            name_norm  player_id               name_md
# 30          Kyrie Irving         kyrie irving  irvinky01          Kyrie Irving
# 31        Brandon Clarke       brandon clarke  clarkbr01        Brandon Clarke
# 32      Dereck Lively II        dereck lively  livelde01      Dereck Lively II
# 33       P.J. Washington        pj washington  washipj01       P.J. Washington
# 34         Klay Thompson        klay thompson  thompkl01         Klay Thompson
# 35          Jaylen Wells         jaylen wells  wellsja01          Jaylen Wells
# 36        Daniel Gafford       daniel gafford  gaffoda01        Daniel Gafford
# 37          Nikola Jokic         nikola jokic  jokicni01          Nikola Jokić
# 38         Stephen Curry        stephen curry  curryst01         Stephen Curry
# 39        Andrew Wiggins       andrew wiggins  wiggian01        Andrew Wiggins
# 40          Jamal Murray         jamal murray  murraja01          Jamal Murray
# 41     Michael Porter Jr       michael porter  portemi01    Michael Porter Jr.
# 42      Jonathan Kuminga     jonathan kuminga  kuminjo01      Jonathan Kuminga
# 43          Aaron Gordon         aaron gordon  gordoaa01          Aaron Gordon
# 44       Christian Braun      christian braun  braunch01       Christian Braun
# 45          Kevon Looney         kevon looney  looneke01          Kevon Looney
# 46    Brandin Podziemski   brandin podziemski  podzibr01    Brandin Podziemski
# 47         Peyton Watson        peyton watson  watsope01         Peyton Watson
# 48  Trayce Jackson-Davis  trayce jacksondavis  jackstr02  Trayce Jackson-Davis
# 49        Alperen Sengun       alperen sengun  sengual01        Alperen Sengun
# 50          De'Aaron Fox          deaaron fox    foxde01          De'Aaron Fox
# 51      Domantas Sabonis     domantas sabonis  sabondo01      Domantas Sabonis
# 52           Jalen Green          jalen green  greenja05           Jalen Green
# 53         Fred VanVleet        fred vanvleet  vanvlfr01         Fred VanVleet
# 54         Dillon Brooks        dillon brooks  brookdi01         Dillon Brooks
# 55       Jabari Smith Jr         jabari smith  smithja05      Jabari Smith Jr.
# 56         Keegan Murray        keegan murray  murrake02         Keegan Murray
# 57         DeMar DeRozan        demar derozan  derozde01         DeMar DeRozan
# 58            Malik Monk           malik monk   monkma01            Malik Monk
# 59         Deandre Ayton        deandre ayton  aytonde01         Deandre Ayton
# 60           Ivica Zubac          ivica zubac  zubaciv01           Ivica Zubac
# 61         Norman Powell        norman powell  powelno01         Norman Powell
# 62          James Harden         james harden  hardeja01          James Harden
# 63          Jerami Grant         jerami grant  grantje01          Jerami Grant
# 64       Anfernee Simons      anfernee simons  simonan01       Anfernee Simons
# 65        Shaedon Sharpe       shaedon sharpe  sharpsh01        Shaedon Sharpe
# 66         Derrick Jones        derrick jones  jonesde02     Derrick Jones Jr.
# 67        Toumani Camara       toumani camara  camarto01        Toumani Camara
# 68             Kris Dunn            kris dunn   dunnkr01             Kris Dunn
# 69      Donovan Mitchell     donovan mitchell  mitchdo01      Donovan Mitchell
# 70         Jarrett Allen        jarrett allen  allenja01         Jarrett Allen
# 71           Evan Mobley          evan mobley  mobleev01           Evan Mobley
# 72        Darius Garland       darius garland  garlada01        Darius Garland
# 73           Isaac Okoro          isaac okoro  okorois01           Isaac Okoro
# 74          Jordan Poole         jordan poole  poolejo01          Jordan Poole
# 75             Alex Sarr            alex sarr   sarral01             Alex Sarr
# 76       Malcolm Brogdon      malcolm brogdon  brogdma01       Malcolm Brogdon
# 77       Bilal Coulibaly      bilal coulibaly  coulibi01       Bilal Coulibaly
# 78     Marvin Bagley III        marvin bagley        NaN                   NaN
# 79     Jonas Valanciunas    jonas valanciunas  valanjo01     Jonas Valančiūnas

# %%
games =  pd.read_csv('../data/rosters.nosync/rosters_2025.csv')

# %%
games[(games['game_id'].apply(lambda x: x.startswith('20241205'))) & (games['starter'])]
# Out:
#            game_id            Player  player_id Team         MP  FG  FGA  \
# 7048  202412050CLE     Jarrett Allen  allenja01  CLE  35.366667   3    5
# 7049  202412050CLE    Darius Garland  garlada01  CLE  33.250000   9   20
# 7050  202412050CLE  Donovan Mitchell  mitchdo01  CLE  32.933333  11   24
# 7051  202412050CLE       Evan Mobley  mobleev01  CLE  32.250000   7   11
# 7052  202412050CLE       Isaac Okoro  okorois01  CLE  11.633333   1    2
# ...            ...               ...        ...  ...        ...  ..  ...
# 7208  202412050WAS       Luka Dončić  doncilu01  DAL  32.400000   7   17
# 7209  202412050WAS      Kyrie Irving  irvinky01  DAL  24.800000  10   16
# 7210  202412050WAS   P.J. Washington  washipj01  DAL  24.483333   2    7
# 7211  202412050WAS     Klay Thompson  thompkl01  DAL  21.300000   4    9
# 7212  202412050WAS  Dereck Lively II  livelde01  DAL  19.000000   3    6
#
#         FG%  3P  3PA  ...  AST%  STL%  BLK%  TOV%  USG%   ORtg   DRtg   BPM  \
# 7048  0.600   0    0  ...  19.0   2.5   0.0  25.4   9.1  145.0  100.0   6.2
# 7049  0.450   3   10  ...  17.0   0.0   0.0   4.5  27.3  115.0  111.0  -2.7
# 7050  0.458   6   10  ...  28.2   2.7   4.0  17.2  35.8  102.0  101.0   4.9
# 7051  0.636   3    5  ...  16.3   4.1   0.0   6.8  18.5  149.0  100.0  12.1
# 7052  0.500   1    2  ...  19.2   0.0   0.0   0.0   7.0  171.0  111.0   0.2
# ...     ...  ..  ...  ...   ...   ...   ...   ...   ...    ...    ...   ...
# 7208  0.412   3   10  ...  39.4   2.9   2.5  17.2  29.4  120.0   93.0   3.3
# 7209  0.625   3    5  ...  20.3   3.8   0.0  10.4  32.0  138.0   98.0   7.6
# 7210  0.286   2    4  ...   8.9   0.0   6.6   0.0  14.7  148.0   99.0   3.2
# 7211  0.444   3    5  ...  11.6   0.0   0.0  10.0  19.3  129.0  110.0  -1.3
# 7212  0.500   0    0  ...   6.3   2.5   4.3  14.3  15.1  138.0   95.0  -2.3
#
#       VORP  starter
# 7048   6.1     True
# 7049  -0.5     True
# 7050   4.8     True
# 7051   9.5     True
# 7052   0.5     True
# ...    ...      ...
# 7208   3.6     True
# 7209   5.0     True
# 7210   2.6     True
# 7211   0.3     True
# 7212  -0.1     True
#
# [80 rows x 42 columns]

# %%
season = 2025
today = datetime.now(ZoneInfo('America/New_York'))


url = f'https://www.basketball-reference.com/leagues/NBA_{season}_games-{today.strftime("%B").lower()}.html'
page = requests.get(url)
soup = BeautifulSoup(page.content, 'lxml')
table = soup.find('table')
while table.find_all('tr', class_ = 'thead') :
    table.find('tr', class_ = 'thead').decompose()
games = pd.read_html(str(table))[0].rename(columns = {'Start (ET)': 'Time'})
games['Home'] = [x['href'].split('/')[2] for x in table.find_all('a', href = True) if 'teams' in x['href']][1::2]
games['Away'] = [x['href'].split('/')[2] for x in table.find_all('a', href = True) if 'teams' in x['href']][0::2]
games['Date'] = pd.to_datetime(games['Date'])
games = games[pd.to_datetime(games['Date']) == pd.to_datetime(today.date())].reset_index(drop = True)
games['Time'] = (games['Date'].astype(str) + ' ' +  games['Time']).apply(lambda x: datetime.strptime(x.upper() + 'M', "%Y-%m-%d %I:%M%p"))
games['game_id'] = games['Date'].apply(lambda x: datetime.strftime(x, "%Y%m%d")) + '0' + games['Home']
games = games[['game_id', 'Date', 'Time', 'Home', 'Away']]

# %%
if os.getenv("GITHUB_ACTIONS") == "true" :
        api_key = os.getenv('ODDS_API_KEY')
else :
    with open('secrets/odds_api_key.txt') as f:
        api_key = f.read()

# %%
tmrw_utc = (today + timedelta(days = 1)).astimezone(pytz.utc)

# %%
tmrw_utc.strftime('%Y-%m-%dT%H:%M:%SZ')
# Out:
# '2024-11-28T00:47:06Z'

# %%
events_response = requests.get(f'https://api.the-odds-api.com/v4/sports/basketball_nba/events',
                               params = {'apiKey': api_key,
                                         'commenceTimeTo': tmrw_utc.strftime('%Y-%m-%dT%H:%M:%SZ')})

# %%
odds = pd.DataFrame(events_response.json()).rename(columns = {'id': 'event_id'})
odds['commence_time'] = pd.to_datetime(odds['commence_time'])

# %%
odds = odds.head(5)
odds
# Out:
#                            event_id       sport_key sport_title  \
# 0  8371571bb6059f03debc55b594422565  basketball_nba         NBA
# 1  979282582fedc5d942f4f0f2f22763ee  basketball_nba         NBA
# 2  312350cf1c97873d6cb81224bac3873e  basketball_nba         NBA
# 3  0a3002d2aaa7b94c5c9c4d3bf792ac7d  basketball_nba         NBA
# 4  0ae85f4502bca2d13e62d2e35c94744c  basketball_nba         NBA
#
#               commence_time               home_team           away_team
# 0 2024-11-27 00:10:00+00:00      Washington Wizards       Chicago Bulls
# 1 2024-11-27 00:35:00+00:00              Miami Heat     Milwaukee Bucks
# 2 2024-11-27 01:00:00+00:00  Minnesota Timberwolves     Houston Rockets
# 3 2024-11-27 02:00:00+00:00               Utah Jazz   San Antonio Spurs
# 4 2024-11-27 03:00:00+00:00            Phoenix Suns  Los Angeles Lakers

# %%
with open('utils/odds_tm_map.json', 'r') as f :
    odds_tm_map = json.load(f)

# %%
odds['game_id'] = today.strftime('%Y%m%d') + '0' + odds['home_team'].map(odds_tm_map)

# %%
games.merge(
    odds[['game_id', 'event_id']],
    on = 'game_id',
    how = 'left'
)
# Out:
#         game_id       Date                Time Home Away  \
# 0  202411260WAS 2024-11-26 2024-11-26 19:00:00  WAS  CHI
# 1  202411260MIA 2024-11-26 2024-11-26 19:30:00  MIA  MIL
# 2  202411260MIN 2024-11-26 2024-11-26 20:00:00  MIN  HOU
# 3  202411260UTA 2024-11-26 2024-11-26 21:00:00  UTA  SAS
# 4  202411260PHO 2024-11-26 2024-11-26 22:00:00  PHO  LAL
#
#                            event_id
# 0  8371571bb6059f03debc55b594422565
# 1  979282582fedc5d942f4f0f2f22763ee
# 2  312350cf1c97873d6cb81224bac3873e
# 3  0a3002d2aaa7b94c5c9c4d3bf792ac7d
# 4  0ae85f4502bca2d13e62d2e35c94744c

# %%
gms = pd.read_csv('data/games.csv')
gms.insert(5, 'event_id', np.nan)

# %%
gms.to_csv('data/games.csv', index = None)

# %%
def datetime_to_cron_utc(t) :
    t_et = pd.to_datetime(t).replace(tzinfo = pytz.timezone('US/Eastern'))
    t_utc = t_et.astimezone(pytz.utc)
    return f"{t_utc.minute} {t_utc.hour} {t_utc.day} {t_utc.month} *"

# %%
[(t, datetime_to_cron_utc(pd.to_datetime(t) - timedelta(minutes = 30))) for t in games['Time'].unique()]
# Out:
# [(numpy.datetime64('2024-11-26T19:00:00.000000000'), '30 23 26 11 *'),
#  (numpy.datetime64('2024-11-26T19:30:00.000000000'), '0 0 27 11 *'),
#  (numpy.datetime64('2024-11-26T20:00:00.000000000'), '30 0 27 11 *'),
#  (numpy.datetime64('2024-11-26T21:00:00.000000000'), '30 1 27 11 *'),
#  (numpy.datetime64('2024-11-26T22:00:00.000000000'), '30 2 27 11 *')]

# %%
odds_response = requests.get(f'https://api.the-odds-api.com/v4/sports/basketball_nba/events/{eventId}/odds',
                             params = {'apiKey': api_key,
                                       'regions': 'us',
                                       'markets': 'player_first_basket',
                                       'oddsFormat': 'decimal'})

# %%
fanduel_idx = np.argmax(['fanduel' in x['key'] for x in odds_response.json()['bookmakers']])
odds = odds_response.json()['bookmakers'][fanduel_idx]['markets'][0]

# %%
odds_df = (
    pd.DataFrame(odds['outcomes'])
    .rename(columns = {'description': 'player', 'price': 'decimal_odds'})
    .drop(columns = 'name')
)

# %%
odds_df['event_id'] = eventId
# Out:
#             player  decimal_odds
# 0    Deandre Ayton           6.5
# 1  Anthony Edwards           7.0
# 2    Julius Randle           7.5
# 3     Jerami Grant           7.5
# 4      Rudy Gobert           8.5
# 5  Anfernee Simons           9.0
# 6   Shaedon Sharpe          10.0
# 7   Toumani Camara          11.0
# 8  Jaden McDaniels          11.0
# 9      Mike Conley          14.0

# %%
# Scrape historical first basket
# Predict first basket scorer
#   PPG
#   VORP, OWS, ...
#   USG%
#   First basket history


# Scrape historical tip-off winners
# Predict tip-off winner
#   Height
#   Tip-off winning ratio
#   Rebounds

# %%
pd.DataFrame(events_response.json())
# Out:
#                                   id       sport_key sport_title  \
# 0   84d6b1ca05b2ad858b5b9ac52ea4b0ee  basketball_nba         NBA
# 1   1e6137994854a6163d6f9fea8dc6e83e  basketball_nba         NBA
# 2   808cd638f31e1657b3c5cd3841a76b4a  basketball_nba         NBA
# 3   74058cb479045efa21ebd5c57050e23e  basketball_nba         NBA
# 4   e80e0c514aa69872360f58b079796a8b  basketball_nba         NBA
# 5   2d650fff73dcc627c1c0de3a4694e9fc  basketball_nba         NBA
# 6   30e4d7fc5396e7b0b8be16b278c123fe  basketball_nba         NBA
# 7   6050b0be3ce7b57b77ef6695b9cecaa1  basketball_nba         NBA
# 8   f0bfcb563a5de00b392bda6960db1796  basketball_nba         NBA
# 9   4a86e15d2c8c52972524be69d15941cc  basketball_nba         NBA
# 10  973a6ea86af7d9e2bf4c52509822f5bf  basketball_nba         NBA
# 11  07a07eaa8f786d68cb371107f36f5b33  basketball_nba         NBA
# 12  6f66bc2154fb45b2047e1c1c5afcdc38  basketball_nba         NBA
# 13  bc6f994bad539db5054c8b750c437fb8  basketball_nba         NBA
# 14  22a9b650e64ca15cb0c83dc0148a571e  basketball_nba         NBA
#
#            commence_time               home_team               away_team
# 0   2024-11-08T01:10:00Z           Chicago Bulls  Minnesota Timberwolves
# 1   2024-11-08T01:10:00Z         Milwaukee Bucks               Utah Jazz
# 2   2024-11-08T01:10:00Z       San Antonio Spurs  Portland Trail Blazers
# 3   2024-11-13T00:00:00Z          Boston Celtics           Atlanta Hawks
# 4   2024-11-13T00:00:00Z         Detroit Pistons              Miami Heat
# 5   2024-11-13T00:30:00Z      Philadelphia 76ers         New York Knicks
# 6   2024-11-13T01:00:00Z         Milwaukee Bucks         Toronto Raptors
# 7   2024-11-13T02:00:00Z               Utah Jazz            Phoenix Suns
# 8   2024-11-13T03:00:00Z   Golden State Warriors        Dallas Mavericks
# 9   2024-11-13T03:00:00Z  Portland Trail Blazers  Minnesota Timberwolves
# 10  2024-12-25T17:00:00Z         New York Knicks       San Antonio Spurs
# 11  2024-12-25T19:30:00Z        Dallas Mavericks  Minnesota Timberwolves
# 12  2024-12-25T22:00:00Z          Boston Celtics      Philadelphia 76ers
# 13  2024-12-26T01:00:00Z   Golden State Warriors      Los Angeles Lakers
# 14  2024-12-26T03:30:00Z            Phoenix Suns          Denver Nuggets

# %%
import requests
from bs4 import BeautifulSoup
from scrape import getId

# %%
url = f'https://www.basketball-reference.com/boxscores/?month=11&day=12&year=2024'
page = requests.get(url)
soup = BeautifulSoup(page.content, 'lxml')

# %%
page
# Out:
# <Response [200]>

# %%
game_ids = [getId(x) for x in soup.find_all('a', href = True) if 'boxscores/pbp' in x['href']]

# %%
game_ids
# Out:
# ['202411120BOS',
#  '202411120DET',
#  '202411120GSW',
#  '202411120MIL',
#  '202411120ORL',
#  '202411120PHI',
#  '202411120POR',
#  '202411120UTA']

# %%
from datetime import datetime, timedelta
from zoneinfo import ZoneInfo
from time import sleep

from scrape import get_first_basket, getId


yst = datetime.now(ZoneInfo('America/New_York')) - timedelta(days = 1)

# %%
yst.month
# Out:
# 11

# %%
url = 'https://www.nba.com/stats/draft/combine-anthro'
page = requests.get(url)

# %%
html = str(BeautifulSoup(page.content, 'lxml'))

# %%
html.split('<table')
# Out:
# ['<!DOCTYPE html>\n<html data-build="17287" data-version="4.52.0" lang="en"><head><meta charset="utf-8"/><link href="/site-manifest.json" rel="manifest"/><meta content="width=device-width,initial-scale=1,minimum-scale=1,maximum-scale=1,user-scalable=no" name="viewport"/><script src="/newrelic/newrelic-prod.js"></script><script id="theme-loader" src="/theme-loader.js"></script><title>Draft Combine Anthrometric | Stats | NBA.com</title><meta content="NBA Draft Combine Anthrometric data" name="description"/><link href="/favicon.ico" rel="icon"/><link href="/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/><link href="/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/><link href="/apple-touch-icon.png" rel="apple-touch-icon"/><link href="/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/><link href="/apple-touch-icon.png" rel="apple-touch-icon" sizes="120x120"/><link href="/apple-touch-icon.png"/><meta content="#da532c" name="msapplication-TileColor"/><link color="#051c2d" href="/safari-pinned-tab.svg" rel="mask-icon"/><meta content="16" name="next-head-count"/><link crossorigin="" href="https://fonts.gstatic.com" rel="preconnect"/><link as="style" href="/_next/static/css/ca09f40369912838.css" rel="preload"/><link data-n-g="" href="/_next/static/css/ca09f40369912838.css" rel="stylesheet"/><link as="style" href="/_next/static/css/0e62c9b82960de26.css" rel="preload"/><link data-n-p="" href="/_next/static/css/0e62c9b82960de26.css" rel="stylesheet"/><link as="style" href="/_next/static/css/f02ab47ebdb7cbde.css" rel="preload"/><link data-n-p="" href="/_next/static/css/f02ab47ebdb7cbde.css" rel="stylesheet"/><noscript data-n-css=""></noscript><script defer="" nomodule="" src="/_next/static/chunks/polyfills-c67a75d1b6f99dc8.js"></script><script defer="" src="/_next/static/chunks/webpack-f3c9ea85e12074c2.js"></script><script defer="" src="/_next/static/chunks/framework-6a24ea55bfe2d3c0.js"></script><script defer="" src="/_next/static/chunks/main-878323283d90b24a.js"></script><script defer="" src="/_next/static/chunks/pages/_app-ca9ee772a114f309.js"></script><script defer="" src="/_next/static/chunks/33907-5d11dce992822776.js"></script><script defer="" src="/_next/static/chunks/33288-6f44bfc701c7d2c4.js"></script><script defer="" src="/_next/static/chunks/62058-d878f4bc34973523.js"></script><script defer="" src="/_next/static/chunks/21062-e31abd069e3236b6.js"></script><script defer="" src="/_next/static/chunks/68885-47f0bfa86def704d.js"></script><script defer="" src="/_next/static/chunks/9066-f4160f2aef0823c1.js"></script><script defer="" src="/_next/static/chunks/25046-c209eff68a2c2b7f.js"></script><script defer="" src="/_next/static/chunks/38134-18b7e5a1271a15ef.js"></script><script defer="" src="/_next/static/chunks/49561-4e8694d7565651e3.js"></script><script defer="" src="/_next/static/chunks/pages/stats/draft/combine-anthro-8708170c473213d5.js"></script><script defer="" src="/_next/static/XNiYH4ngaClxUpc6v5-aR/_buildManifest.js"></script><script defer="" src="/_next/static/XNiYH4ngaClxUpc6v5-aR/_ssgManifest.js"></script><style data-href="https://fonts.googleapis.com/css?family=Roboto:300,400,700,900|Roboto+Condensed:400,700|Roboto+Slab:400,700&amp;display=swap">@font-face{font-family:\'Roboto\';font-style:normal;font-weight:300;font-display:swap;src:url(https://fonts.gstatic.com/s/roboto/v32/KFOlCnqEu92Fr1MmSU5fBBc-.woff) format(\'woff\')}@font-face{font-family:\'Roboto\';font-style:normal;font-weight:400;font-display:swap;src:url(https://fonts.gstatic.com/s/roboto/v32/KFOmCnqEu92Fr1Mu4mxM.woff) format(\'woff\')}@font-face{font-family:\'Roboto\';font-style:normal;font-weight:700;font-display:swap;src:url(https://fonts.gstatic.com/s/roboto/v32/KFOlCnqEu92Fr1MmWUlfBBc-.woff) format(\'woff\')}@font-face{font-family:\'Roboto\';font-style:normal;font-weight:900;font-display:swap;src:url(https://fonts.gstatic.com/s/roboto/v32/KFOlCnqEu92Fr1MmYUtfBBc-.woff) format(\'woff\')}@font-face{font-family:\'Roboto ...
