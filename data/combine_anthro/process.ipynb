# %%
import pandas as pd
import numpy as np
import csv

# %%
measure_cols = {
        'HEIGHT W/O SHOES': 'height',
        'STANDING REACH': 'standing_reach',
        'WINGSPAN': 'wingspan'
    }

def ft_to_cm(x, year) :
    if not pd.isna(x) :
        if year not in [2020, 2021] :
            if ' ' in x :
                ft, inch = x.split(' ')
                ft = int(ft.strip("'"))
                inch = float(inch.strip("'"))
                return round(2.54 * (12 * ft + inch), 2)
            else :
                return np.nan
        else:
            ft, inch = x.split("'")
            ft = int(ft)
            inch = float(inch.strip("'"))
            return round(2.54 * (12 * ft + inch), 2)
    else :
        return np.nan

# %%
for year in np.arange(2020, 2022) :

    with open(f'report_{year}.txt', 'r') as f :
        table_str = f.read()

    lines = table_str.replace('\t', ',').splitlines()

    with open('temp.csv', 'w', newline='') as csvfile :
        writer = csv.writer(csvfile)
        for line in lines :
            writer.writerow(line.split(','))

    data = pd.read_csv('temp.csv')
    for col in measure_cols.keys() :
        data[col] = data[col].apply(lambda x: ft_to_cm(x, year))
    data = data.rename(columns =  {'PLAYER': 'name'} | measure_cols)[['name'] + list(measure_cols.values())]
    data.insert(1, 'Year', year)

    # data.to_csv('../combine_anthro.csv', index = None, header = None, mode = 'a')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 15
#      13 data = pd.read_csv('temp.csv')
#      14 for col in measure_cols.keys() :
# ---> 15     data[col] = data[col].apply(lambda x: ft_to_cm(x, year))
#      16 data = data.rename(columns =  {'PLAYER': 'name'} | measure_cols)[['name'] + list(measure_cols.values())]
#      17 data.insert(1, 'Year', year)
#
# File /opt/anaconda3/envs/penv/lib/python3.9/site-packages/pandas/core/series.py:4917, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
# -> 4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
#    4924     ).apply()
#
# File /opt/anaconda3/envs/penv/lib/python3.9/site-packages/pandas/core/apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File /opt/anaconda3/envs/penv/lib/python3.9/site-packages/pandas/core/apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File /opt/anaconda3/envs/penv/lib/python3.9/site-packages/pandas/core/base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File /opt/anaconda3/envs/penv/lib/python3.9/site-packages/pandas/core/algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[34], line 15, in <lambda>(x)
#      13 data = pd.read_csv('temp.csv')
#      14 for col in measure_cols.keys() :
# ---> 15     data[col] = data[col].apply(lambda x: ft_to_cm(x, year))
#      16 data = data.rename(columns =  {'PLAYER': 'name'} | measure_cols)[['name'] + list(measure_cols.values())]
#      17 data.insert(1, 'Year', year)
#
# Cell In[33], line 18, in ft_to_cm(x, year)
#      16         return np.nan
#      17 else:
# ---> 18     ft, inch = x.split("'")
#      19     ft = int(ft)
#      20     inch = float(inch.strip("'"))
#
# ValueError: too many values to unpack (expected 2)

# %%
pd.read_csv('temp.csv')
# Out:
#                 PLAYER    POS BODY FAT %  HAND LENGTH (inches)  \
# 0            Max Abmas     PG      5.50%                  8.00
# 1         Ochai Agbaji     SG      4.15%                  9.00
# 2        Marcus Bagley     SF      7.50%                  8.75
# 3       Scottie Barnes     SF      5.30%                  9.25
# 4       Charles Bassey      C      5.90%                  9.00
# ..                 ...    ...        ...                   ...
# 60       Aaron Wiggins  SG-SF      5.00%                  8.75
# 61     Ziaire Williams     SF      4.40%                  9.00
# 62        Moses Wright     PF      5.60%                  9.00
# 63  McKinley Wright IV     PG      6.70%                  8.50
# 64   Marcus Zegarowski     PG      7.20%                  8.00
#
#     HAND WIDTH (inches) HEIGHT W/O SHOES HEIGHT W/ SHOES STANDING REACH  \
# 0                  7.75         5'10.5''       5'11.75''       7'10.0''
# 1                  8.75          6'4.5''         6'5.5''        8'7.5''
# 2                  8.50          6'6.0''        6'7.75''        8'6.5''
# 3                 10.25          6'7.0''         6'8.0''        9'0.0''
# 4                  9.50         6'9.25''       6'10.25''       8'11.5''
# ..                  ...              ...             ...            ...
# 60                 8.50          6'4.5''         6'5.0''        8'7.0''
# 61                 8.75         6'8.25''        6'9.75''       8'10.5''
# 62                 9.50         6'7.75''         6'9.0''       8'11.0''
# 63                 9.00        5'11.25''        6'0.25''       7'10.0''
# 64                 9.50         6'0.75''         6'2.0''        8'0.0''
#
#     WEIGHT (LBS)   WINGSPAN
# 0          161.8   6'1.75''
# 1          214.4   6'10.0''
# 2          216.8   6'11.0''
# 3          225.4   7'2.75''
# 4          230.2    7'3.0''
# ..           ...        ...
# 60         190.0   6'9.75''
# 61         188.4  6'10.25''
# 62         225.8   7'0.75''
# 63         192.2   6'5.25''
# 64         180.8   6'2.75''
#
# [65 rows x 10 columns]
